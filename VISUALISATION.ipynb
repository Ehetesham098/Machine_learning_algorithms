# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,20,4)
y=np.linspace(1,10,8)

# %%
x
# Out:
# array([ 1,  5,  9, 13, 17])

# %%
y
# Out:
# array([ 1.        ,  2.28571429,  3.57142857,  4.85714286,  6.14285714,
#         7.42857143,  8.71428571, 10.        ])

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d8b592bf313e> in <module>
# ----> 1 plt.plot(x,y)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
# ...

# %%
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("freq")
plt.ylabel("vel")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-962a8866d7ab> in <module>
# ----> 1 plt.plot(x,y)
#       2 plt.xlabel("freq")
#       3 plt.ylabel("vel")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.plot(x,y,'green')
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-c572c92f7780> in <module>
# ----> 1 plt.plot(x,y,'green')
#       2 plt.xlabel("freq")
#       3 plt.ylabel("vel")
#       4 plt.title("Graph")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
# Out:
# Text(0.5, 1.0, 'fhfj')

# %%
plt.plot(x,y)

# %%
x=np.arange(1,20,3)
y=np.linspace(1,10,7)
plt.plot(x,y)
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
plt.plot(x1,y1)

# %%
x=np.arange(1,20,3)
y=np.linspace(1,10,7)
plt.plot(x,y,label='plot1',color='green')
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
plt.legend()
plt.plot(x1,y1,label='plot2',color='orange')
plt.legend()

# %%
x=np.arange(1,20,3)
y=np.linspace(1,10,7)
plt.bar(x,y,label='plot1',color='green')
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
plt.legend()
plt.bar(x1,y1,label='plot2',color='orange')
plt.legend()

# %%
x=np.arange(1,20,3)
y=np.linspace(1,10,7)
plt.plot(x,y,label='plot1',color='green')
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
plt.legend()
plt.bar(x1,y1,label='plot2',color='orange')
plt.legend()

# %%
x=np.arange(1,20,3)
y=np.linspace(1,10,7)
plt.bar(x,y,label='plot1',color='green')
plt.xlabel("freq")
plt.ylabel("vel")
plt.title("Graph")
x1=[1,2,4,7,8]
y1=[1,3,2.5,4,6]
plt.scatter(x1,y1,color='r')
plt.xlabel('hh')
plt.ylabel('wh')
plt.title('fhfj')
plt.legend()
plt.plot(x1,y1,label='plot2',color='orange')
plt.legend()

# %%
list=[50,55,68,73]
labels=["m","p","c","b"]
plt.pie(list,labels=labels)
plt.legend()
plt.plot()
# Out:
# []

# %%
x=np.linspace(1,10,8)
y=x**2
plt.subplot(2,2,1)
plt.plot(x,y,'red')
plt.subplot(2,2,2)
plt.plot(x1,y1)
plt.subplot(2,2,3)
plt.plot(x,y,'red')
plt.subplot(2,2,4)
plt.plot(x1,y1)
plt.show()

# %%
fig=plt.figure()
axes=fig.axes([0.1,0.1,0.8,0.8])
axes2=fig.axes([0.2,0.4,0.3,0.4])
axes.plot(x,y,'blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d596117438e9> in <module>
#       1 fig=plt.figure()
# ----> 2 axes=fig.axes([0.1,0.1,0.8,0.8])
#       3 axes2=fig.axes([0.2,0.4,0.3,0.4])
#       4 axes.plot(x,y,'blue')
#
# TypeError: 'list' object is not callable

# %%
import seaborn as sns
sns.load_dataset()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-6e91ba1534e6> in <module>
#       1 import seaborn as sns
# ----> 2 sns.load_dataset()
#
# TypeError: load_dataset() missing 1 required positional argument: 'name'

# %%
g=sns.Pairplot(iris)
g.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-675fbabe6663> in <module>
# ----> 1 g=sns.Pairplot(iris)
#       2 g.map(plt.scatter)
#
# AttributeError: module 'seaborn' has no attribute 'Pairplot'

# %%
sns.heatmap(tips.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-7ebab8d3a18f> in <module>
# ----> 1 sns.heatmap(tips.corr())
#
# NameError: name 'tips' is not defined

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
tips.tail()
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris=sns.load_dataset("iris")
iris.tail()
sns.pairplot(iris)

# %%
import seaborn as sns
sns.heatmap(tips.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3738c024c97> in <module>
#       1 import seaborn as sns
# ----> 2 sns.heatmap(tips.corr())
#
# NameError: name 'tips' is not defined
